# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import scipy.special as special
import scipy.optimize as optimize
import seaborn as sns
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('Paris_50_Columnas.csv')
df.head(2)
# Out:
# C:\Users\joker\AppData\Local\Temp\ipykernel_11672\4219480268.py:1: DtypeWarning: Columns (12,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Paris_50_Columnas.csv')
#    Unnamed: 0    id                        listing_url last_scraped  \
# 0           0  3109  https://www.airbnb.com/rooms/3109   2024-09-11
# 1           1  5396  https://www.airbnb.com/rooms/5396   2024-09-13
#
#                                          description  host_id  \
# 0  Lovely Appartment with one bedroom with a Quee...     3631
# 1  NEW SOFA-BED SINCE JUNE 2023, Please disregard...     7903
#
#                                  host_url  host_since host_response_time  \
# 0  https://www.airbnb.com/users/show/3631  2008-10-14     within an hour
# 1  https://www.airbnb.com/users/show/7903  2009-02-14     within an hour
#
#   host_response_rate  ... review_scores_checkin review_scores_communication  \
# ...

# %% [markdown]
# **Regresión logistica "host is superhost"**

# %%
df[["price", "host_total_listings_count", "review_scores_communication"]].apply(pd.to_numeric, errors="coerce").isna().sum()
# Out:
# price                          0
# host_total_listings_count      6
# review_scores_communication    0
# dtype: int64

# %%
df["host_total_listings_count"] = pd.to_numeric(df["host_total_listings_count"].replace("No Hay", 0))

# %%
df[["price", "host_total_listings_count", "review_scores_communication"]].apply(pd.to_numeric, errors="coerce").isna().sum()
# Out:
# price                          0
# host_total_listings_count      0
# review_scores_communication    0
# dtype: int64

# %%
Vars_Indep = df[['price','host_total_listings_count','review_scores_communication']]
Var_dep = df['host_is_superhost']

# %%
X = Vars_Indep
Y = Var_dep

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=None)

# %%
escalar = StandardScaler()

# %%
X_train = escalar.fit_transform(X_train)
X_test = escalar.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
algoritmo = LogisticRegression(class_weight='balanced')
algoritmo.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced')

# %%
y_pred = algoritmo.predict(X_test)
y_pred
# Out:
# array(['t', 'f', 't', ..., 't', 't', 'f'], dtype=object)

# %%
#Matriz de confusión
from sklearn.metrics import confusion_matrix
matriz = confusion_matrix(y_test, y_pred)
print(matriz)
# Out:
# [[13570  9810]
#  [ 1474  3785]]

# %%
from sklearn.metrics import precision_score
precision = precision_score(y_test, y_pred, average="binary", pos_label="f")
print('precision: ',precision)
# Out:
# precision:  0.9020207391651157

# %%
from sklearn.metrics import accuracy_score
exactitud = accuracy_score(y_test, y_pred)  
print("exatitud: ",exactitud)
# Out:
# exatitud:  0.6059918293236496

# %%
from sklearn.metrics import recall_score
sensibilidad = recall_score(y_test, y_pred, average="binary", pos_label="f")
print("Sensibilidad del modelo:")
print("sensibilidad: ",sensibilidad)
# Out:
# Sensibilidad del modelo:
# sensibilidad:  0.5804106073567151

# %% [markdown]
# **Regresión logistica "instant_bookable"**

# %%
unico = np.unique(df['instant_bookable'])
unico
# Out:
# array(['f', 't'], dtype=object)

# %%
Vars_Indep = df[['number_of_reviews','host_total_listings_count','review_scores_checkin']]
Var_dep = df['instant_bookable']

# %%
X = Vars_Indep
Y = Var_dep

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=None)

# %%
escalar = StandardScaler()

# %%
X_train = escalar.fit_transform(X_train)
X_test = escalar.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
algoritmo = LogisticRegression()
algoritmo.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = algoritmo.predict(X_test)
y_pred
# Out:
# array(['f', 'f', 'f', ..., 'f', 'f', 'f'], dtype=object)

# %%
#Matriz de confusión
from sklearn.metrics import confusion_matrix
matriz = confusion_matrix(y_test, y_pred)
print(matriz)
# Out:
# [[21136   428]
#  [ 6255   820]]

# %%
from sklearn.metrics import precision_score
precision = precision_score(y_test, y_pred, average="binary", pos_label="f")
print('precision: ',precision)
# Out:
# precision:  0.7716403198130772

# %%
from sklearn.metrics import accuracy_score
exactitud = accuracy_score(y_test, y_pred)  
print("exatitud: ",exactitud)
# Out:
# exatitud:  0.7666468801284961

# %%
from sklearn.metrics import recall_score
sensibilidad = recall_score(y_test, y_pred, average="binary", pos_label="f")
print("sensibilidad: ",sensibilidad)
# Out:
# sensibilidad:  0.9801521053607865

# %% [markdown]
# **Regresión logistica "host_response_time"**

# %%
unico = np.unique(df['host_response_time'])
unico
# Out:
# array(['a few days or more', 'within a day', 'within a few hours',
#        'within an hour'], dtype=object)

# %%
df['host_response_time'] = df['host_response_time'].replace(['a few days or more','within a day', 'within a few hours'],'NO within an hour')

# %%
Vars_Indep = df[['number_of_reviews','host_total_listings_count','review_scores_communication']]
Var_dep = df['host_response_time']

# %%
X = Vars_Indep
Y = Var_dep
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=None)
escalar = StandardScaler()

# %%
X_train = escalar.fit_transform(X_train)
X_test = escalar.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
algoritmo = LogisticRegression()
algoritmo.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = algoritmo.predict(X_test)
y_pred
# Out:
# array(['within an hour', 'within an hour', 'within an hour', ...,
#        'within an hour', 'within an hour', 'within an hour'], dtype=object)

# %%
#Matriz de confusión
from sklearn.metrics import confusion_matrix
matriz = confusion_matrix(y_test, y_pred)
print(matriz)
# Out:
# [[    0  5933]
#  [    5 22701]]

# %%
from sklearn.metrics import precision_score
precision = precision_score(y_test, y_pred, average="binary", pos_label="within an hour")
print('precision: ',precision)
# Out:
# precision:  0.7927987706921841

# %%
from sklearn.metrics import accuracy_score
exactitud = accuracy_score(y_test, y_pred)  
print("exatitud: ",exactitud)
# Out:
# exatitud:  0.7926603582527323

# %%
from sklearn.metrics import recall_score
sensibilidad = recall_score(y_test, y_pred, average="binary", pos_label="within an hour")
print("sensibilidad: ",sensibilidad)
# Out:
# sensibilidad:  0.9997797938870783

# %% [markdown]
# **Regresión logistica "room_type"**

# %%
unico = np.unique(df['room_type'])
unico
# Out:
# array(['Entire home/apt', 'Hotel room', 'Private room', 'Shared room'],
#       dtype=object)

# %%
df['room_type'] = df['room_type'].replace(['Entire home/apt','Hotel room', 'Shared room'],'NO Private room')

# %%
Vars_Indep = df[['bedrooms','price','beds']]
Var_dep = df['room_type']

# %%
X = Vars_Indep
Y = Var_dep
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=None)
escalar = StandardScaler()

# %%
X_train = escalar.fit_transform(X_train)
X_test = escalar.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
algoritmo = LogisticRegression(class_weight='balanced')
algoritmo.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced')

# %%
y_pred = algoritmo.predict(X_test)
y_pred
# Out:
# array(['NO Private room', 'Private room', 'Private room', ...,
#        'NO Private room', 'Private room', 'Private room'], dtype=object)

# %%
#Matriz de confusión
from sklearn.metrics import confusion_matrix
matriz = confusion_matrix(y_test, y_pred)
print(matriz)
# Out:
# [[17217  8699]
#  [ 1467  1256]]

# %%
from sklearn.metrics import precision_score
precision = precision_score(y_test, y_pred, average="binary", pos_label="Private room")
print('precision: ',precision)
# Out:
# precision:  0.12616775489703666

# %%
from sklearn.metrics import accuracy_score
exactitud = accuracy_score(y_test, y_pred)  
print("exatitud: ",exactitud)
# Out:
# exatitud:  0.6450295052201543

# %%
from sklearn.metrics import recall_score
sensibilidad = recall_score(y_test, y_pred, average="binary", pos_label="Private room")
print("sensibilidad: ",sensibilidad)
# Out:
# sensibilidad:  0.4612559676827029

# %% [markdown]
# **Regresión logistica "review_scores cleanliness"**

# %%
# 1. Eliminar filas con valores nulos en la variable objetivo
df = df.dropna(subset=['review_scores_cleanliness'])

# %%
# 2. Crear variable binaria: 1 si limpieza >= 4.8, 0 si < 4.8
df['cleanliness_binaria'] = df['review_scores_cleanliness'].apply(lambda x: 1 if x >= 4.8 else 0).astype(int)

# %%
# 3. Definir variables independientes y dependiente
Vars_Indep = df[['room_type','price','host_is_superhost']]
Var_dep = df['cleanliness_binaria']  # ¡¡¡Esto es CLAVE!!!

# %%
# 4. One-hot encoding
X = pd.get_dummies(Vars_Indep, drop_first=True)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Var_dep, test_size=0.3, random_state=42)

# %%
escalar = StandardScaler()

# %%
X_train = escalar.fit_transform(X_train)
X_test = escalar.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
algoritmo = LogisticRegression(class_weight='balanced')
algoritmo.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced')

# %%
y_pred = algoritmo.predict(X_test)
y_pred
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
#Matriz de confusión
from sklearn.metrics import confusion_matrix
matriz = confusion_matrix(y_test, y_pred)
print(matriz)
# Out:
# [[16211  2301]
#  [ 7083  3044]]

# %%
from sklearn.metrics import precision_score
precision = precision_score(y_test, y_pred, average="binary", pos_label=1)
print('precision: ',precision)
# Out:
# precision:  0.5695042095416277

# %%
from sklearn.metrics import accuracy_score
exactitud = accuracy_score(y_test, y_pred)  
print("exactitud: ",exactitud)
# Out:
# exactitud:  0.6723349278955271

# %%
from sklearn.metrics import recall_score
sensibilidad = recall_score(y_test, y_pred, average="binary", pos_label=1)
print("Sensibilidad del modelo:")
print("sensibilidad: ",sensibilidad)
# Out:
# Sensibilidad del modelo:
# sensibilidad:  0.30058260096771006

# %% [markdown]
# **Regresión logistica "host_identity_verified"**

# %%
# Reemplazar 'No Hay' por 0 en las variables independientes
vars_indep_cols = ['price', 'number_of_reviews', 'review_scores_communication']
df[vars_indep_cols] = df[vars_indep_cols].replace('No Hay', 0)

# Reemplazar 'No Hay' por 'f' en la variable dependiente
df['host_identity_verified'] = df['host_identity_verified'].replace('No Hay', 'f')

# Convertir a tipo numérico las independientes
df[vars_indep_cols] = df[vars_indep_cols].apply(pd.to_numeric)

# Finalmente, asignar X e Y
X = df[vars_indep_cols]
Y = df['host_identity_verified']

# %%
#Matriz de confusión
from sklearn.metrics import confusion_matrix
matriz = confusion_matrix(y_test, y_pred)
print(matriz)
# Out:
# [[16211  2301]
#  [ 7083  3044]]

# %%
Vars_Indep = df[['price','number_of_reviews','review_scores_communication']]
Var_dep = df['host_identity_verified']

# %%
df[df['host_identity_verified'] == 'No Hay']
# Out:
# Empty DataFrame
# ...

# %%
X = Vars_Indep
Y = Var_dep

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=None)

# %%
escalar = StandardScaler()

# %%
X_train = escalar.fit_transform(X_train)
X_test = escalar.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
algoritmo = LogisticRegression(class_weight='balanced')
algoritmo.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced')

# %%
y_pred = algoritmo.predict(X_test)
y_pred
# Out:
# array(['f', 'f', 't', ..., 't', 't', 'f'], dtype=object)

# %%
#Matriz de confusión
from sklearn.metrics import confusion_matrix
matriz = confusion_matrix(y_test, y_pred)
print(matriz)
# Out:
# [[ 2316   475]
#  [17372  8476]]

# %%
from sklearn.metrics import precision_score
precision = precision_score(y_test, y_pred, average="binary", pos_label="f")
print('precision: ',precision)
# Out:
# precision:  0.11763510767980495

# %%
from sklearn.metrics import accuracy_score
exactitud = accuracy_score(y_test, y_pred)  
print("exatitud: ",exactitud)
# Out:
# exatitud:  0.37682879988826423

# %%
from sklearn.metrics import recall_score
sensibilidad = recall_score(y_test, y_pred, average="binary", pos_label="f")
print("Sensibilidad del modelo:")
print("sensibilidad: ",sensibilidad)
# Out:
# Sensibilidad del modelo:
# sensibilidad:  0.8298101039054102

# %% [markdown]
# **Regresión logistica "has_availability"**

# %%
Vars_Indep = df[['number_of_reviews','host_total_listings_count','review_scores_checkin']]
Var_dep = df['has_availability']

# %%
X = Vars_Indep
Y = Var_dep

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=None)

# %%
escalar = StandardScaler()

# %%
X_train = escalar.fit_transform(X_train)
X_test = escalar.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
algoritmo = LogisticRegression(class_weight='balanced')
algoritmo.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced')

# %%
y_pred = algoritmo.predict(X_test)
y_pred
# Out:
# array(['f', 'f', 't', ..., 't', 't', 't'], dtype=object)

# %%
#Matriz de confusión
from sklearn.metrics import confusion_matrix
matriz = confusion_matrix(y_test, y_pred)
print(matriz)
# Out:
# [[ 1394   146]
#  [12783 14316]]

# %%
from sklearn.metrics import precision_score
precision = precision_score(y_test, y_pred, average="binary", pos_label="f")
print('precision: ',precision)
# Out:
# precision:  0.09832827819707977

# %%
from sklearn.metrics import accuracy_score
exactitud = accuracy_score(y_test, y_pred)  
print("exactitud: ",exactitud)
# Out:
# exactitud:  0.548552672928524

# %%
from sklearn.metrics import recall_score
sensibilidad = recall_score(y_test, y_pred, average="binary", pos_label="f")
print("Sensibilidad del modelo:")
print("sensibilidad: ",sensibilidad)
# Out:
# Sensibilidad del modelo:
# sensibilidad:  0.9051948051948052

# %% [markdown]
# **Regresión logistica "review_scores_communication"**

# %%
# 1. Eliminar filas con valores nulos en la variable objetivo
df = df.dropna(subset=['review_scores_communication'])

# %%
# 2. Crear variable binaria: 1 si limpieza >= 4.8, 0 si < 4.8
df['communication_binaria'] = df['review_scores_communication'].apply(lambda x: 1 if x >= 4.8 else 0).astype(int)

# %%
# 3. Definir variables independientes y dependiente
Vars_Indep = df[['host_response_rate','number_of_reviews','price']]
Var_dep = df['cleanliness_binaria']  # ¡¡¡Esto es CLAVE!!!

# %%
# 4. One-hot encoding
X = pd.get_dummies(Vars_Indep, drop_first=True)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Var_dep, test_size=0.3, random_state=42)

# %%
escalar = StandardScaler()

# %%
X_train = escalar.fit_transform(X_train)
X_test = escalar.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
algoritmo = LogisticRegression(class_weight='balanced')
algoritmo.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced')

# %%
y_pred = algoritmo.predict(X_test)
y_pred
# Out:
# array([0, 1, 0, ..., 0, 0, 1])

# %%
#Matriz de confusión
from sklearn.metrics import confusion_matrix
matriz = confusion_matrix(y_test, y_pred)
print(matriz)
# Out:
# [[10950  7562]
#  [ 4348  5779]]

# %%
from sklearn.metrics import precision_score
precision = precision_score(y_test, y_pred, average="binary", pos_label=1)
print('precision: ',precision)
# Out:
# precision:  0.43317592384378983

# %%
from sklearn.metrics import accuracy_score
exactitud = accuracy_score(y_test, y_pred)  
print("exactitud: ",exactitud)
# Out:
# exactitud:  0.584133524215231

# %%
from sklearn.metrics import recall_score
sensibilidad = recall_score(y_test, y_pred, average="binary", pos_label=1)
print("Sensibilidad del modelo:")
print("sensibilidad: ",sensibilidad)
# Out:
# Sensibilidad del modelo:
# sensibilidad:  0.5706527105756888

# %% [markdown]
# **Regresión logistica "Accommodates"**

# %%
# 1. Eliminar filas con valores nulos en la variable objetivo
df = df.dropna(subset=['accommodates'])

# %%
# 2. Crear variable binaria: 1 si limpieza >= 3, 0 si < 3
df['accommodates_binaria'] = df['accommodates'].apply(lambda x: 1 if x >= 3 else 0).astype(int)

# %%
# 3. Definir variables independientes y dependiente
Vars_Indep = df[['bathrooms','price','beds']]
Var_dep = df['accommodates_binaria']

# %%
# 4. One-hot encoding
X = pd.get_dummies(Vars_Indep, drop_first=True)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Var_dep, test_size=0.3, random_state=42)

# %%
escalar = StandardScaler()

# %%
X_train = escalar.fit_transform(X_train)
X_test = escalar.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
algoritmo = LogisticRegression(class_weight='balanced')
algoritmo.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced')

# %%
y_pred = algoritmo.predict(X_test)
y_pred
# Out:
# array([0, 0, 1, ..., 1, 1, 0])

# %%
#Matriz de confusión
from sklearn.metrics import confusion_matrix
matriz = confusion_matrix(y_test, y_pred)
print(matriz)
# Out:
# [[ 7953  5994]
#  [ 1583 13109]]

# %%
from sklearn.metrics import precision_score
precision = precision_score(y_test, y_pred, average="binary", pos_label=1)
print('precision: ',precision)
# Out:
# precision:  0.6862272941422813

# %%
from sklearn.metrics import accuracy_score
exactitud = accuracy_score(y_test, y_pred)  
print("exactitud: ",exactitud)
# Out:
# exactitud:  0.7354307063794127

# %%
from sklearn.metrics import recall_score
sensibilidad = recall_score(y_test, y_pred, average="binary", pos_label=1)
print("Sensibilidad del modelo:")
print("sensibilidad: ",sensibilidad)
# Out:
# Sensibilidad del modelo:
# sensibilidad:  0.8922542880479173

# %% [markdown]
# **Regresión logistica "minimum_nights"**

# %%
# 1. Eliminar filas con valores nulos en la variable objetivo
df = df.dropna(subset=['minimum_nights'])

# %%
# 2. Crear variable binaria: 1 si limpieza >= 4.8, 0 si < 4.8
df['minimum_binaria'] = df['minimum_nights'].apply(lambda x: 1 if x >= 2 else 0).astype(int)

# %%
# 3. Definir variables independientes y dependiente
Vars_Indep = df[['price','number_of_reviews','accommodates']]
Var_dep = df['minimum_binaria']

# %%
# 4. One-hot encoding
X = pd.get_dummies(Vars_Indep, drop_first=True)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Var_dep, test_size=0.3, random_state=42)

# %%
escalar = StandardScaler()

# %%
X_train = escalar.fit_transform(X_train)
X_test = escalar.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
algoritmo = LogisticRegression(class_weight='balanced')
algoritmo.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced')

# %%
y_pred = algoritmo.predict(X_test)
y_pred
# Out:
# array([0, 1, 1, ..., 1, 1, 1])

# %%
#Matriz de confusión
from sklearn.metrics import confusion_matrix
matriz = confusion_matrix(y_test, y_pred)
print(matriz)
# Out:
# [[ 2852  4075]
#  [ 9024 12688]]

# %%
from sklearn.metrics import precision_score
precision = precision_score(y_test, y_pred, average="binary", pos_label=1)
print('precision: ',precision)
# Out:
# precision:  0.7569050885879616

# %%
from sklearn.metrics import accuracy_score
exactitud = accuracy_score(y_test, y_pred)  
print("exactitud: ",exactitud)
# Out:
# exactitud:  0.542616711477356

# %%
from sklearn.metrics import recall_score
sensibilidad = recall_score(y_test, y_pred, average="binary", pos_label=1)
print("Sensibilidad del modelo:")
print("sensibilidad: ",sensibilidad)
# Out:
# Sensibilidad del modelo:
# sensibilidad:  0.5843773028739867
